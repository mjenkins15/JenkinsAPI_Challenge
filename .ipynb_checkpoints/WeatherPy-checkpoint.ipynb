# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats
import json
from pprint import pprint

# Import API key
from api_keys import weather_api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Day 2 APIs, Activity 5 for reference

url= f"http://api.openweathermap.org/data/2.5/weather?lat=35&lon=139&appid={weather_api_key}"
units = "imperial"


#Build partial query URl
query_url = f"{url}appid={weather_api_key}&units={units}&q="
response = requests.get(url)
weather =response.json()

pprint(weather)
#response.text
# Out:
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 35, 'lon': 139},
#  'dt': 1587177533,
#  'id': 1851632,
#  'main': {'feels_like': 288.89,
#           'humidity': 91,
#           'pressure': 1004,
#           'temp': 288.34,
#           'temp_max': 289.26,
#           'temp_min': 287.59},
#  'name': 'Shuzenji',
#  'rain': {'1h': 12.95},
#  'sys': {'country': 'JP',
#          'id': 2019346,
#          'sunrise': 1587154086,
#          'sunset': 1587201490,
#          'type': 3},
#  'timezone': 32400,
#  'weather': [{'description': 'heavy intensity rain',
#               'icon': '10d',
#               'id': 502,
#               'main': 'Rain'}],
#  'wind': {'deg': 172, 'gust': 2.68, 'speed': 0.89}}

# %%
#Day 2 APIs, Activity 5  and Activity 8 for reference

number = 1 

#Set up lists to hold response info
city_name = []
temp = []
humidity = []
cloudiness = []
wind_speed = []
lat = []
lng = []

for city in cities: 
    try:
        response = requests.get(url + '&q=' + city).json()
        city_name.append(response['name'])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        print(f"Success")
    except KeyError:
        print: ("Unknown Data")
        number = number + 1
        
        
print(response)
print(city_name)
print(temp)
print(humidity)
print(cloudiness)
print(wind_speed)
print(lat)

print
# Out:
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# {'coord': {'lon': 38.93, 'lat': -4.93}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 296.76, 'feels_like': 298.45, 'temp_min': 296.76, 'temp_max': 296.76, 'pressure': 1010, 'humidity': 89, 'sea_level': 1010, 'grnd_level': 995}, 'wind': {'speed': 4.06, 'deg': 225}, 'rain': {'3h': 3.95}, 'clouds': {'all': 98}, 'dt': 1587177637, 'sys': {'country': 'TZ', 'sunrise': 1587180227, 'sunset': 1587223375}, 'timezone': 10800, 'id': 153423, 'name': 'Mlalo', 'cod': 200}
# ['Rikitea', 'Yellowknife', 'Punta Arenas', 'Vaini', 'Buraidah', 'Vostok', 'Busselton', "Krasnosel'kup", 'Tasiilaq', 'Lompoc', 'Martinsville', 'Pisco', 'Lata', 'Pacific Grove', 'Qeshm', 'Thompson', 'Kutum', 'Mataura', 'Vestmannaeyjar', 'Lagoa', 'Salalah', 'New Norfolk', 'Shimoda', 'Monte Patria', 'Cape Town', 'Leh', 'Port Alfred', 'Floriano', 'George Town', 'Filingué', 'Puquio', 'Hammerfest', 'Tiksi', 'Chui', 'Hithadhoo', 'Ushuaia', 'Tuktoyaktuk', 'Qaanaaq', 'Ubari', 'Nola', 'Arrondissement de Bourg-en-Bresse', 'Saint-Philippe', 'Bethel', 'Upata', 'Mariehamn', 'Cap-aux-Meules', 'Bengkulu', 'Dikson', 'Mogadishu', 'Ghoti', 'Bredasdorp', 'Esim', 'Mehamn', 'Brigantine', 'Sistranda', 'El Espino', 'Eichstätt', 'Half Moon Bay', 'Jijiga', 'Tuatapere', 'Otradnoye', 'Aldan', 'Goderich', 'Diego de Almagro', 'Butaritari', 'Arlit', 'Carnarvon', 'Puerto Ayora', 'Hilo', 'Ikorodu', 'Luanda', 'Vardø', 'Chokurdakh', 'Hermanus', 'Erzin', 'Castro', 'Albany', 'Bluff', 'Yar-Sale', 'Luba', 'Beira', 'Te Anau', 'Arica', 'Fort Nelson', 'Saint George', 'Atuona', "Severo-Kuril'sk", 'Port Hedland', 'Nampula', 'Deputatsky', 'Kouroussa', 'Aksha', 'Chimbarongo', 'Naze', 'Walvis Bay', 'Ponta do Sol', 'Port Elizabeth', 'Hobart', 'Roebourne', 'Morondava', 'Torrington', 'Anori', 'Xining', 'Barrow', 'Airai', 'Rapid Valley', 'Touros', 'Mwingi', 'Berlevåg', 'Pingliang', 'Jamestown', 'Waipawa', 'Avarua', 'Anadyr', 'Yulara', 'Nouadhibou', 'Kapaa', 'Norrtälje', 'Geraldton', 'Upernavik', 'Katherine', 'Miranda de Ebro', 'Ancud', 'Grand Gaube', 'Ossora', 'Tomatlán', 'Vanavara', 'Hong Kong', 'Two Rivers', 'Gemeente Wageningen', 'Rāvar', 'Buala', 'Ahipara', 'Zemetchino', 'Hasaki', 'Belfast', 'Korhogo', 'Qandala', 'Jalu', 'Dalby', 'Katsuura', 'Turbat', 'El Viejo', 'Djibouti', 'Jinchang', 'Port Blair', 'Akçaabat', 'San Policarpo', 'Eskil', 'Taltal', 'Bhairab Bāzār', 'Nikolskoye', 'Namatanai', 'Grindavik', 'Dingle', 'Aloja', 'Kabale', 'Okhotsk', 'Tura', 'Lorengau', 'Provideniya', 'Santa Cruz', 'Longyearbyen', 'Ganzhou', 'Labuhan', 'Cayenne', 'Esperance', 'Saskylakh', 'Ilulissat', 'Obo', 'Paranaíba', 'Nome', 'Leningradskiy', 'Monrovia', 'Ampanihy', 'Grong', 'Mossamedes', 'Tokur', 'Karasjok', 'Ostrovnoy', 'Härnösand', 'Waingapu', 'Nālūt', 'Norman Wells', 'Puerto Madryn', 'Mthatha', 'São Filipe', 'Meulaboh', 'Maxixe', 'Poya', 'Saldanha', 'Tautira', 'Erenhot', 'Oistins', 'Nanlong', 'Champerico', 'Wodonga', 'Faanui', 'Brae', 'Arraial do Cabo', 'Torbay', 'Lebu', 'Vila do Maio', 'Lavrentiya', 'Bambous Virieux', 'Jurm', 'Mar del Plata', 'Pimenta Bueno', 'Cidreira', 'Nazca', 'Pevek', 'Concordia', 'Buin', 'Sembakung', 'Kavieng', 'Sechura', 'Christchurch', 'Mahébourg', 'San Patricio', 'Vila Velha', 'Daura', 'Los Chiles', 'Sambava', 'Hervey Bay', 'Mokhsogollokh', 'Qaryat Sulūq', 'Meyzieu', 'Tazovsky', 'Dao', 'Srednekolymsk', 'Panzhihua', 'Sombreffe', 'Kalghatgi', 'San Francisco del Mar Viejo', 'Koson', 'Asău', 'North B
60.72, 62.16, -16.52, 48.57, 64.86, 46.71, 38.89, -8.76, 60.55, 52.63, -14.28, -13.2, -12.23, -28.24, 23.17, 31.63, -22.45, 7.62, 54.08, 30.44, 55.3, 33.43, 59.37, 53.07, -38.55, 7.04, 11.65, -8.35, 53.05, 39.5, -3.1, 23.57, -17.71, -34.73, 61.67, 55.34, 40.85, -23.13, -20.46, 29.56, 40.28, 61.03, 39.47, 37.2, -0.09, 29.27, 17.8, 58.96, 49.5, 29.6, 45.36, 13.22, 0.85, -34.48, -15.53, 18.47, 55.96, 70.24, 42.37, 37.68, 52.26, 16.53, -5.06, 39.45, -4.93]
# <function print>

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Day 2 APIs, Activity 5 for reference

#Create Data Frame
response_df= pd. DataFrame({
        'City':city_name,
        'Temperature': temp,
        'Humidity': humidity,
        'Cloudiness': cloudiness,
        'Wind Speed': wind_speed,
        'Latitude': lat,
        'Longitude': lng})

response_df.head()
# Out:
#            City  Temperature  Humidity  Cloudiness  Wind Speed  Latitude  \
# 0       Rikitea       298.35        63           1        0.89    -23.12
# 1   Yellowknife       270.53        63          90        4.10     62.46
# 2  Punta Arenas       279.98        75          14        4.60    -53.15
# 3         Vaini       301.15        65          20        5.70    -21.20
# 4      Buraidah       293.15        49          20        3.10     26.33
#
#    Longitude
# 0    -134.97
# 1    -114.35
# 2     -70.92
# 3    -175.20
# 4      43.98

# %%
#Export the city data into a .csv. 
pd.DataFrame.to_csv(response_df, 'response.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
response_df.head()
# Out:
#             City  Temperature  Humidity  Cloudiness  Wind Speed  Latitude  \
# 0      Hithadhoo       301.99        76          69        3.38     -0.60
# 1        Erenhot       281.66        32         100        4.76     43.65
# 2    Morgan City       299.74        65          40        4.60     29.70
# 3          Bluff       283.71        92          78        2.68    -46.60
# 4  San Cristobal       305.15        49          40        4.10      7.77
#
#    Longitude
# 0      73.08
# 1     111.98
# 2     -91.21
# 3     168.33
# 4     -72.22

# %%
#plt.scatter(response_df["Latitude"], response_df['Temperature'],marker='o')
#plt.show()

response_df.plot(kind = "scatter", x="Latitude", y="Temperature", title="Latitude vs.Temperature")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#plt.scatter(response_df["Latitude"], response_df['Humidity'],marker='o')
#plt.show()

response_df.plot(kind = "scatter", x="Latitude", y="Humidity", title="Latitude vs.Humidity")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
response_df.plot(kind = "scatter", x="Latitude", y="Cloudiness", title="Latitude vs.Cloudiness")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
response_df.plot(kind = "scatter", x="Latitude", y="Wind Speed", title="Latitude vs. Wind Speed ")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
north_hem=response_df[response_df["Latitude"]>=0]
south_hem=response_df[response_df["Latitude"]<=0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Day 2 API's Activity 7 Stu_Weather_plots for reference

x_values = north_hem["Latitude"]
y_values = north_hem["Temperature"]

#Perform a linear regression on Temp Vs Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

#Get regression values
regress_values = x_values * slope + intercept
print(regress_values) 

#Create line equation string
line_eq = f"y ={round(slope,2)}x +  {round(intercept,2)}"
line_eq

#Create plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
         
#Label plot and annotacte the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title("Northern Hemisphere - Latitude vs. Temperature ")
plt.annotate(line_eq,(15,45),color="red")
         
#Print r square value
print(f"The r-squared is: {rvalue**2}")
         
# Show plot
plt.show()
# Out:
# 1      272.530651
# 4      292.430324
# 5      281.326604
# 7      270.746124
# 8      270.795695
#           ...
# 556    283.595816
# 557    286.178974
# 558    278.148605
# 559    297.827966
# 561    285.204093
# Name: Latitude, Length: 379, dtype: float64
# The r-squared is: 0.8036316598163675

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Day 2 API's Activity 7 Stu_Weather_plots for reference

x_values = south_hem["Latitude"]
y_values = south_hem["Temperature"]

#Perform a linear regression on Temp Vs Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

#Get regression values
regress_values = x_values * slope + intercept
print(regress_values) 

#Create line equation string
line_eq = f"y ={round(slope,2)}x +  {round(intercept,2)}"
line_eq

#Create plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
         
#Label plot and annotacte the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title("Southern Hemisphere - Latitude vs. Temperature ")
plt.annotate(line_eq,(15,45),fontsize=15,color="red")
         
#Print r square value
print(f"The r-squared is: {rvalue**2}")
         
# Show plot
plt.show()
# Out:
# 0      293.952834
# 2      284.840575
# 3      294.535437
# 6      290.757627
# 11     296.811226
#           ...
# 542    300.941024
# 551    290.505773
# 552    296.255933
# 560    299.432935
# 562    299.472382
# Name: Latitude, Length: 184, dtype: float64
# The r-squared is: 0.42190440277324553

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Day 2 API's Activity 7 Stu_Weather_plots for reference

x_values = north_hem["Latitude"]
y_values = north_hem["Humidity"]

#Perform a linear regression on Temp Vs Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

#Get regression values
regress_values = x_values * slope + intercept
print(regress_values) 

#Create line equation string
line_eq = f"y ={round(slope,2)}x +  {round(intercept,2)}"
line_eq

#Create plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
         
#Label plot and annotacte the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Northern Hemisphere - Latitude vs. Humidity")
plt.annotate(line_eq,(15,45),fontsize=15,color="red")
         
#Print r square value
print(f"The r-squared is: {rvalue**2}")
         
# Show plot
plt.show()
# Out:
# 1      76.155596
# 4      64.425820
# 5      70.970859
# 7      77.207477
# 8      77.178258
#          ...
# 556    69.633282
# 557    68.110651
# 558    72.844117
# 559    61.244203
# 561    68.685290
# Name: Latitude, Length: 379, dtype: float64
# The r-squared is: 0.08298907073176615

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_hem["Latitude"]
y_values = south_hem["Humidity"]

#Perform a linear regression on Temp Vs Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

#Get regression values
regress_values = x_values * slope + intercept
print(regress_values) 

#Create line equation string
line_eq = f"y ={round(slope,2)}x +  {round(intercept,2)}"
line_eq

#Create plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
         
#Label plot and annotacte the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Northern Hemisphere - Latitude vs. Humidity")
plt.annotate(line_eq,(15,45),fontsize=15,color="red")
         
#Print r square value
print(f"The r-squared is: {rvalue**2}")
         
# Show plot
plt.show()
# Out:
# 0      71.591938
# 2      63.751947
# 3      72.093196
# 6      68.842850
# 11     74.051236
#          ...
# 542    77.604425
# 551    68.626160
# 552    73.573474
# 560    76.306897
# 562    76.340837
# Name: Latitude, Length: 184, dtype: float64
# The r-squared is: 0.04093268544606969

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_hem["Latitude"]
y_values = north_hem["Cloudiness"]

#Perform a linear regression on Temp Vs Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

#Get regression values
regress_values = x_values * slope + intercept
print(regress_values) 

#Create line equation string
line_eq = f"y ={round(slope,2)}x +  {round(intercept,2)}"
line_eq

#Create plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
         
#Label plot and annotacte the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Northern Hemisphere - Latitude vs. Cloudiness")
plt.annotate(line_eq,(15,45),fontsize=15,color="red")
         
#Print r square value
print(f"The r-squared is: {rvalue**2}")
         
# Show plot
plt.show()
# Out:
# 1      61.403468
# 4      49.070366
# 5      55.952052
# 7      62.509453
# 8      62.478731
#          ...
# 556    54.545676
# 557    52.944728
# 558    57.921662
# 559    45.725101
# 561    53.548924
# Name: Latitude, Length: 379, dtype: float64
# The r-squared is: 0.028324007655941313

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_hem["Latitude"]
y_values = south_hem["Cloudiness"]

#Perform a linear regression on Temp Vs Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

#Get regression values
regress_values = x_values * slope + intercept
print(regress_values) 

#Create line equation string
line_eq = f"y ={round(slope,2)}x +  {round(intercept,2)}"
line_eq

#Create plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
         
#Label plot and annotacte the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Southern Hemisphere - Latitude vs. Cloudiness")
plt.annotate(line_eq,(15,45),fontsize=15,color="red")
         
#Print r square value
print(f"The r-squared is: {rvalue**2}")
         
# Show plot
plt.show()
# Out:
# 0      50.957013
# 2      24.018899
# 3      52.679329
# 6      41.511180
# 11     59.407130
#          ...
# 542    71.615846
# 551    40.766637
# 552    57.765547
# 560    67.157556
# 562    67.274172
# Name: Latitude, Length: 184, dtype: float64
# The r-squared is: 0.1027605788714522

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_hem["Latitude"]
y_values = north_hem["Wind Speed"]

#Perform a linear regression on Temp Vs Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

#Get regression values
regress_values = x_values * slope + intercept
print(regress_values) 

#Create line equation string
line_eq = f"y ={round(slope,2)}x +  {round(intercept,2)}"
line_eq

#Create plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
         
#Label plot and annotacte the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Southern Hemisphere - Latitude vs. Wind Speed")
plt.annotate(line_eq,(15,45),fontsize=15,color="red")
         
#Print r square value
print(f"The r-squared is: {rvalue**2}")
         
# Show plot
plt.show()
# Out:
# 1      4.543827
# 4      3.513026
# 5      4.088197
# 7      4.636265
# 8      4.633697
#          ...
# 556    3.970653
# 557    3.836845
# 558    4.252817
# 559    3.233429
# 561    3.887344
# Name: Latitude, Length: 379, dtype: float64
# The r-squared is: 0.04273859243538941

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_hem["Latitude"]
y_values = south_hem["Wind Speed"]

#Perform a linear regression on Temp Vs Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

#Get regression values
regress_values = x_values * slope + intercept
print(regress_values) 

#Create line equation string
line_eq = f"y ={round(slope,2)}x +  {round(intercept,2)}"
line_eq

#Create plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
         
#Label plot and annotacte the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Southern Hemisphere -Latitude vs. Wind Speed")
plt.annotate(line_eq,(15,45),fontsize=15,color="red")
         
#Print r square value
print(f"The r-squared is: {rvalue**2}")
         
# Show plot
plt.show()
# Out:
# 0      2.888418
# 2      4.276668
# 3      2.799659
# 6      3.375207
# 11     2.452943
#          ...
# 542    1.823769
# 551    3.413577
# 552    2.537542
# 560    2.053526
# 562    2.047517
# Name: Latitude, Length: 184, dtype: float64
# The r-squared is: 0.10652821755594664
