# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprint import pprint
# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#Load the CSV from WeatherPy
weather_data = pd.read_csv("response.csv")
weather_data
# Out:
#      Unnamed: 0           City  Temperature  Humidity  Cloudiness  Wind Speed  \
# 0             0          Kumul        19.42        14          24        2.45
# 1             1   Ponta do Sol        14.93        59          20        2.10
# 2             2         Albany         4.11        39           1        1.50
# 3             3    Tuktoyaktuk       -12.85        84          90        5.70
# 4             4        Ushuaia         6.15        75          75       19.00
# ..          ...            ...          ...       ...         ...         ...
# 532         532          Bilma        28.42        13           0        2.88
# 533         533  Kiryat Shmona        18.86        93           8        1.50
# 534         534       Dengzhou         7.55        50           4       12.25
# 535         535       Matagami        -0.85        58          90        6.70
# 536         536    Verkhoyansk        -4.81        88          96        1.46
#
#      Latitude  Longitude
# 0       42.80      93.45
# 1       32.67     -17.10
# 2       42.60     -73.97
# 3       69.45    -133.04
# 4      -54.80     -68.30
# ..        ...        ...
# 532     18.69      12.92
# 533     33.21      35.57
# 534     37.81     120.75
# 535     49.75     -77.63
# 536     67.54     133.38
#
# [537 rows x 8 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#API's Day 3, Activity 10
#Drop NA rows
#weather_data = weather_data.dropna()
#weather_data

# %%
# Used API's Day 3, Activities 6 & 7 for reference

#Locations Data Frame
#temperature = []
#wind_speed = []
#cloudiness = []

#vacation = pd.DataFrame[{"Temperature": Temperature,
  #                       "Cloudiness": Cloudiness}]

#vacation.head()

#Lat and lng as locations
locations = weather_data[["Latitude", "Longitude"]]
locations
# Out:
#      Latitude  Longitude
# 0       42.80      93.45
# 1       32.67     -17.10
# 2       42.60     -73.97
# 3       69.45    -133.04
# 4      -54.80     -68.30
# ..        ...        ...
# 532     18.69      12.92
# 533     33.21      35.57
# 534     37.81     120.75
# 535     49.75     -77.63
# 536     67.54     133.38
#
# [537 rows x 2 columns]

# %%
# Humidity for the Weight
humidity = weather_data["Humidity"].astype(float)
humidity
# Out:
# 0      14.0
# 1      59.0
# 2      39.0
# 3      84.0
# 4      75.0
#        ...
# 532    13.0
# 533    93.0
# 534    50.0
# 535    58.0
# 536    88.0
# Name: Humidity, Length: 537, dtype: float64

# %%
# Used day 3 API's Activity 7, Stu_Airport_Map
# Plot Heatmap
fig = gmaps.figure()

#Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights = humidity,
                                 dissipating = False,max_intensity = 10,
                                point_radius = 1)
#Add layer
fig.add_layer(heat_layer)

#Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#new_cities_df = weather_data.loc[(weather_data["Temperature"]>70), (weather_data["Temperature"]<80), (weather_data["Wind Speed"] <10), (weather_data["Cloudiness"] == 0):]
#new_cities_df = new_cities_df.dropna()

# %%
#Max temp less than 80 degrees but greater than 70 degrees

perfect_temp = weather_data["Temperature"] > 70, weather_data["Temperature"]< 80
perfect_temp


#max_temp = weather["Temperature"]< 80
#max_temp
# Out:
# (0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  532    False
#  533    False
#  534    False
#  535    False
#  536    False
#  Name: Temperature, Length: 537, dtype: bool, 0      True
#  1      True
#  2      True
#  3      True
#  4      True
#         ...
#  532    True
#  533    True
#  534    True
#  535    True
#  536    True
#  Name: Temperature, Length: 537, dtype: bool)

# %%
#Wind Speed less than 10mph
wind_speed = weather_data["Wind Speed"]<10 
wind_speed
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 532     True
# 533     True
# 534    False
# 535     True
# 536     True
# Name: Wind Speed, Length: 537, dtype: bool

# %%
#Zero cloudiness
cloudiness = weather_data["Cloudiness"] == 0
cloudiness
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 532     True
# 533    False
# 534    False
# 535    False
# 536    False
# Name: Cloudiness, Length: 537, dtype: bool

# %%
#new_cities_df = weather_data

# %%
#Combine the ideal weather conditions(temperature, wind speed, and 
#cloudiness) and drop rows that don't contain all three conditions.
new_cities_df = weather_data[weather_data["Temperature"] > 70]
new_cities_df = weather_data[weather_data["Temperature"] < 80]  
new_cities_df = weather_data[weather_data["Wind Speed"] < 10]
new_cities_df = weather_data[weather_data["Cloudiness"] == 0]
new_cities_df = weather_data.dropna()
new_cities_df = weather_data.reset_index()
new_cities_df
# Out:
#      index  Unnamed: 0           City  Temperature  Humidity  Cloudiness  \
# 0        0           0          Kumul        19.42        14          24
# 1        1           1   Ponta do Sol        14.93        59          20
# 2        2           2         Albany         4.11        39           1
# 3        3           3    Tuktoyaktuk       -12.85        84          90
# 4        4           4        Ushuaia         6.15        75          75
# ..     ...         ...            ...          ...       ...         ...
# 532    532         532          Bilma        28.42        13           0
# 533    533         533  Kiryat Shmona        18.86        93           8
# 534    534         534       Dengzhou         7.55        50           4
# 535    535         535       Matagami        -0.85        58          90
# 536    536         536    Verkhoyansk        -4.81        88          96
#
#      Wind Speed  Latitude  Longitude
# 0          2.45     42.80      93.45
# 1          2.10     32.67     -17.10
# 2          1.50     42.60     -73.97
# 3          5.70     69.45    -133.04
# 4         19.00    -54.80     -68.30
# ..          ...       ...        ...
# 532        2.88     18.69      12.92
# 533        1.50     33.21      35.57
# 534       12.25     37.81     120.75
# 535        6.70     49.75     -77.63
# 536        1.46     67.54     133.38
#
# [537 rows x 9 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# Used API's Day 3 Activity 4 and 5 for reference
#Storing "hotel" into variable 
hotel_df = new_cities_df

# %%
#Add column for "Hotel Name"
column=["Hotel Name"]
for col in column:
        new_cities_df[col]= ""
        
new_cities_df.head()
# Out:
#    index  Unnamed: 0          City  Temperature  Humidity  Cloudiness  \
# 0      0           0         Kumul        19.42        14          24
# 1      1           1  Ponta do Sol        14.93        59          20
# 2      2           2        Albany         4.11        39           1
# 3      3           3   Tuktoyaktuk       -12.85        84          90
# 4      4           4       Ushuaia         6.15        75          75
#
#    Wind Speed  Latitude  Longitude Hotel Name
# 0        2.45     42.80      93.45
# 1        2.10     32.67     -17.10
# 2        1.50     42.60     -73.97
# 3        5.70     69.45    -133.04
# 4       19.00    -54.80     -68.30

# %%
#setting variable 
#latitude = weather_data["Latitude"]
#longitude = weather_data["Longitude"]

# %%
#Day 3 API's Activity 4


#Base url
base_url ="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params = {
     "radius": 5000,
     "type": "lodging",
     "key": g_key
}

for i, row in new_cities_df.iterrows():
    params["location"] = f"{row['Latitude']}, {row['Longitude']}"
    hotel_city = row["City"] 
   # params["keyword"] = hotel_city

    
    print(f"Retrieving Results for Index {i}: {hotel_city}")
    
    response = requests.get(base_url, params=params).json()
    results = response["results"]
    
    try:
        print(f"The first hotel is {results[0]['name']}")
        
        new_cities_df.loc[i, "Hotel Name"] = results[0]["name"]
    except(KeyError, IndexError):
        print("No Hotels")
              
        print("________________________________________________")
# Out:
# Retrieving Results for Index 0: Kumul
# The first hotel is Laoyutang Resort
# Retrieving Results for Index 1: Ponta do Sol
# The first hotel is Hotel do Campo
# Retrieving Results for Index 2: Albany
# No Hotels
# ________________________________________________
# Retrieving Results for Index 3: Tuktoyaktuk
# The first hotel is End of The Road Ltd.
# Retrieving Results for Index 4: Ushuaia
# The first hotel is Albatros Hotel
# Retrieving Results for Index 5: Saint George
# The first hotel is Best Western Plus Abbey Inn
# Retrieving Results for Index 6: Rikitea
# The first hotel is Pension Maro'i
# Retrieving Results for Index 7: Hobart
# The first hotel is St Ives Apartments
# Retrieving Results for Index 8: Son La
# The first hotel is Galaxy Grand Hotel
# Retrieving Results for Index 9: Bemidji
# The first hotel is Hampton Inn & Suites Bemidji
# Retrieving Results for Index 10: Kruisfontein
# The first hotel is Oyster Bay House Rental
# Retrieving Results for Index 11: Marsá Maţrūḩ
# The first hotel is Beau Site
# Retrieving Results for Index 12: Hithadhoo
# The first hotel is Scoop Guest House
# Retrieving Results for Index 13: Faya
# The first hotel is مقبرة ال مجمل
# Retrieving Results for Index 14: Poronaysk
# The first hotel is Gostinitsa Sever
# Retrieving Results for Index 15: Collie
# The first hotel is Collie Ridge
# Retrieving Results for Index 16: Butaritari
# The first hotel is Isles Sunset Lodge
# Retrieving Results for Index 17: Bredasdorp
# The first hotel is Bredasdorp Country Manor
# Retrieving Results for Index 18: Rocha
# The first hotel is Beleza Pura B&B
# Retrieving Results for Index 19: Dikson
# No Hotels
# ________________________________________________
# Retrieving Results for Index 20: Fillmore
# The first hotel is Country Trails Inn & Suites
# Retrieving Results for Index 21: Flinders
# The first hotel is Shellharbour Resort & Conference Centre
# Retrieving Results for Index 22: Castro
# The first hotel is CHACARA BAILLY
# Retrieving Results for Index 23: Dayong
# The first hotel is Haiyue Express Hotel
# Retrieving Results for Index 24: Barquisimeto
# The first hotel is POSADA PARAISO DE LARA CA
# Retrieving Results for Index 25: Santo Amaro das Brotas
# The first hotel is POUSADA NELSINHO
# Retrieving Results for Index 26: Vanavara
# The first hotel is Church of Churches
# Retrieving Results for Index 27: Puerto Ayora
# The first hotel is Finch Bay Galapagos Hotel
# Retrieving Results for Index 28: Busselton
# The first hotel is Observatory Guest House
# Retrieving Results for Index 29: Sitka
# The first hotel is Westmark Sitka
# Retrieving Results for Index 30: Naryan-Mar
# The first hotel is Hostel Agat
# Retrieving Results for Index 31: Nanortalik
# The first hotel is NTS Rooms, Nanortalik
# Retrieving Results for Index 32: Longyearbyen
# The first hotel is Radisson Blu Polar Hotel, Spitsbergen
# Retrieving Results for Index 33: Noumea
# The first hotel is Hôtel Le Lagon
# Retrieving Results for Index 34: Port Hardy
# The first hotel is Airport Inn
# Retrieving Results for Index 35: Airai
# The first hotel is Juvinal Martin
# Retrieving Results for Index 36: Sambava
# The first hotel is Melrose
# Retrieving Results for Index 37: Port Elizabeth
# The first hotel is 39 On Nile Guest House
# Retrieving Results for Index 38: Smolenka
# The first hotel is Motel'
# Retrieving Results for Index 39: New Norfolk
# The first hotel is The Shingles Riverside Cottages
# Retrieving Results for Index 40: Iqaluit
# The first hotel is Frobisher Inn
# Retrieving Results for Index 41: São Filipe
# The first hotel is Tortuga B&B
# Retrieving Results for Index 42: Ribeira Grande
# The first hotel is Quinta da Meia Eira
# Retrieving Results for Index 43: Tasiilaq
# The first hotel is The Red House
# Retrieving Results for Index 44: Bambous Virieux
# The first hotel is Casa Tia Villa
# Retrieving Results for Index 45: Bluff
# The first hotel is Bluff Homestead - Guesthouse & Campervan Park
# Retrieving Results for Index 46: Khandyga
# The first hotel is Apel'sin
# Retrieving Results for Index 47: Soyo
# The first hotel is Hotel Mpampa
# Retrieving Results for Index 48: Kiryat Gat
# The first hotel is אהבה ברווחה
# Retrieving Results for Index 49: Alyangula
# The first hotel is Groote Eylandt Lodge
# Retrieving Results for Index 50: Dolores
# The first hotel is Apart Hotel - Arianos
# Retrieving Results for Index 51: Hokitika
# The first hotel is Beachfront Hotel Hokitika
# Retrieving Results for Index 52: Mount Isa
# The first hotel is ibis Styles Mt Isa Verona
# Retrieving Results for Index 53: Praia
# The first hotel is LT Aparthotel
# Retrieving Results for Index 54: Hasaki
# The first hotel is Inubosaki Kanko Hotel
# Retrieving Results for Index 55: Arraial do Cabo
# The first hotel is Pousada Porto Praia
# Retrieving Results for Index 56: Caravelas
# The first hotel is Pousada dos Navegantes
# Retrieving Results for Index 57: Nikolskoye
# The first hotel is Tourist House - Sablino
# Retrieving Results for Index 58: Talnakh
# The first hotel is Talnakh Hotel
# Retrieving Results for Index 59: Yellowknife
# The first hotel is The Explorer Hotel
# Retrieving Results for Index 60: Alofi
# The first hotel is Taloa Heights
# Retrieving Results for Index 61: Hofn
# The first hotel is Hótel Höfn
# Retrieving Results for Index 62: Geraldton
# The first hotel is Broadwater Mariner Resort
# Retrieving Results for Index 63: Esmeraldas
# The first hotel is MinasTec 24 Hrs - Desentupidora em Esmeraldas, Cancelinha, Fernão Dias, Nova Esmeraldas, Santa Quitéria
# Retrieving Results for Index 64: Nishihara
# The first hotel is Minshuku Agaihama
# Retrieving Results for Index 65: Gravdal
# The first hotel is Skreda Rorbusuiter
# Retrieving Results for Index 66: Hūn
# The first hotel is Alrwasi Hotel
# Retrieving Results for Index 67: Khatanga
# The first hotel is Gostinitsa "Zapolyar'ye"
# Retrieving Results for Index 68: Faanui
# The first hotel is Bora-Bora Pearl Beach Resort & Spa
# Retrieving Results for Index 69: Tuatapere
# The first hotel is Tom Cruse Refreshment Company
# Retrieving Results for Index 70: Jamestown
# The first hotel is Hampton Inn & Suites Jamestown
# Retrieving Results for Index 71: Vaini
# The first hotel is Keleti Beach Resort
# Retrieving Results for Index 72: Antofagasta
# The first hotel is Hotel Terrado Suites Antofagasta
# Retrieving Results for Index 73: Punta Arenas
# The first hotel is Hotel Dreams Del Estrecho
# Retrieving Results for Index 74: Lüderitz
# The first hotel is LÜDERITZ NEST HOTEL
# Retrieving Results for Index 75: Fortuna
# The first hotel is Super 8 Fortuna
# Retrieving Results for Index 76: Jalu
# The first hotel is Jalu Hotel
# Retrieving Results for Index 77: Carnarvon
# The first hotel is Hospitality Carnarvon
# Retrieving Results for Index 78: Port Lincoln
# The first hotel is Port Lincoln Hotel
# Retrieving Results for Index 79: Mataura
# The first hotel is Ellie's Villa
# Retrieving Results for Index 80: Pangnirtung
# The first hotel is Kilabuk Lodge
# Retrieving Results for Index 81: Ilulissat
# The first hotel is Hotel Arctic
# Retrieving Results for Index 82: Stornoway
# The first hotel is Caladh Inn
# Retrieving Results for Index 83: College
# The first hotel is Pike's Waterfront Lodge
# Retrieving Results for Index 84: Saldanha
# The first hotel is Blue Bay Lodge
# Retrieving Results for Index 85: Pacific Grove
# The first hotel is Lovers Point Inn
# Retrieving Results for Index 86: Dunedin
# The first hotel is Scenic Hotel Southern Cross
# Retrieving Results for Index 87: Leh
# The first hotel is Hotel Ladakh Greens
# Retrieving Results for Index 88: Batagay
# No Hotels
# ________________________________________________
# Retrieving Results for Index 89: George Town
# The first hotel is Cititel Penang
# Retrieving Results for Index 90: Zhigansk
# The first hotel is Gostinichnyy Kompleks Aylgy
# Retrieving Results for Index 91: Sovetskiy
# The first hotel is Apartment on Kievskaya 29
# Retrieving Results for Index 92: East London
# The first hotel is Tu Casa
# Retrieving Results for Index 93: Morón
# The first hotel is Hotel Morón
# Retrieving Results for Index 94: Guerrero Negro
# The first hotel is Casa Laguna, Bed & Breakfast
# Retrieving Results for Index 95: San Patricio
# The first hotel is Hotel Cabo Blanco
# Retrieving Results for Index 96: Mahébourg
# The first hotel is Shandrani Beachcomber Resort & Spa
# Retrieving Results for Index 97: North Vanlaiphai
# The first hotel is pu lalluna in
# Retrieving Results for Index 98: Chokurdakh
# No Hotels
# ________________________________________________
# Retrieving Results for Index 99: Alice Springs
# The first hotel is Desert Palms Alice Springs
# Retrieving Results for Index 100: Hermanus
# The first hotel is Misty Waves Boutique Hotel
# Retrieving Results for Index 101: Bairiki Village
# The first hotel is Tarawa Boutique Hotel
# Retrieving Results for Index 102: Tiksi
# The first hotel is Arktika
# Retrieving Results for Index 103: Leningradskiy
# No Hotels
# ________________________________________________
# Retrieving Results for Index 104: Mossamedes
# The first hotel is Chik-Chik Namibe
# Retrieving Results for Index 105: San Cristobal
# The first hotel is Pirineos
# Retrieving Results for Index 106: Atar
# The first hotel is Oumou Elghoura
# Retrieving Results for Index 107: Kutum
# The first hotel is Dibbo areaمنطقة دبو
# Retrieving Results for Index 108: Saint-Philippe
# The first hotel is Chambres d'hôte "La Trinité"
# Retrieving Results for Index 109: Ancud
# The first hotel is HOTEL ANCUD DON LUCAS
# Retrieving Results for Index 110: Ghanzi
# The first hotel is Ghanzi Farmhouse
# Retrieving Results for Index 111: Hilo
# The first hotel is Hilo Hawaiian Hotel
# Retrieving Results for Index 112: Aitape
# No Hotels
# ________________________________________________
# Retrieving Results for Index 113: Cape Town
# The first hotel is Southern Sun Waterfront Cape Town
# Retrieving Results for Index 114: Fairbanks
# The first hotel is Westmark Fairbanks Hotel & Conference Center
# Retrieving Results for Index 115: Quelimane
# The first hotel is Hotel Flamingo
# Retrieving Results for Index 116: Port Alfred
# The first hotel is The Halyards Hotel
# Retrieving Results for Index 117: Fort Nelson
# The first hotel is The Fort Nelson Hotel
# Retrieving Results for Index 118: Korla
# The first hotel is Gulisitan Hotel
# Retrieving Results for Index 119: Hong Kong
# The first hotel is Mini Hotel Central
# Retrieving Results for Index 120: Qaanaaq
# The first hotel is Qaanaaq Hotel
# Retrieving Results for Index 121: Atasū
# The first hotel is Dostyk
# Retrieving Results for Index 122: Klaksvík
# The first hotel is Airbnb rooms
# Retrieving Results for Index 123: Saint-François
# The first hotel is Manoir Du Bonheur
# Retrieving Results for Index 124: Kahului
# The first hotel is Maui Seaside Hotel
# Retrieving Results for Index 125: Kapaa
# The first hotel is Sheraton Kauai Resort at Coconut Beach
# Retrieving Results for Index 126: Brekstad
# The first hotel is Orland Kysthotell
# Retrieving Results for Index 127: Bereda
# The first hotel is Pazo de Verdes
# Retrieving Results for Index 128: Saskylakh
# The first hotel is Saskylakh Aeroport
# Retrieving Results for Index 129: Yulara
# The first hotel is Desert Gardens Hotel - Ayers Rock Resort
# Retrieving Results for Index 130: Olafsvik
# The first hotel is Hotel Olafsvik
# Retrieving Results for Index 131: San Quintín
# The first hotel is Old Mill Hotel
# Retrieving Results for Index 132: Mersing
# The first hotel is Timotel Hotel
# Retrieving Results for Index 133: Mékhé
# The first hotel is Hôtel Keur Mame Astou
# Retrieving Results for Index 134: Katsuura
# The first hotel is Katsuura Hotel Mikazuki
# Retrieving Results for Index 135: Barrow
# The first hotel is King Eider Inn
# Retrieving Results for Index 136: Oriximiná
# The first hotel is Pousada Tia Amélia
# Retrieving Results for Index 137: Pimentel
# The first hotel is Casona Del Muelle
# Retrieving Results for Index 138: Gallup
# The first hotel is El Capitan Motel
# Retrieving Results for Index 139: Pingxiang
# The first hotel is Haiyuntian Hotel
# Retrieving Results for Index 140: Winnemucca
# The first hotel is Winners Inn Casino
# Retrieving Results for Index 141: Doha
# The first hotel is Ezdan Hotel
# Retrieving Results for Index 142: Vestmannaeyjar
# The first hotel is Glamping & Camping
# Retrieving Results for Index 143: Tabou
# The first hotel is hotêl doufoulougou
# Retrieving Results for Index 144: Sinnamary
# The first hotel is ALETHEIA Appartement Sinnamary
# Retrieving Results for Index 145: Saint Paul Harbor
# The first hotel is Best Western Kodiak Inn and Convention Center
# Retrieving Results for Index 146: Atuona
# The first hotel is Villa Enata
# Retrieving Results for Index 147: Lavrentiya
# No Hotels
# ________________________________________________
# Retrieving Results for Index 148: Cuamba
# The first hotel is Hotel Vision
# Retrieving Results for Index 149: Greenwood
# The first hotel is Quality Inn Greenwood Hwy 25
# Retrieving Results for Index 150: Pāsighāt
# The first hotel is Siang Guest House
# Retrieving Results for Index 151: Ostrovnoy
# No Hotels
# ________________________________________________
# Retrieving Results for Index 152: Sakakah
# The first hotel is Fakhamat Al Orjoana Apartment
# Retrieving Results for Index 153: Becerril
# The first hotel is Hotel La Candelaria
# Retrieving Results for Index 154: Narsaq
# The first hotel is Hotel Narsaq
# Retrieving Results for Index 155: Lata
# The first hotel is Casa Maquia
# Retrieving Results for Index 156: Bengkulu
# The first hotel is Grage Hotel Bengkulu
# Retrieving Results for Index 157: Calama
# The first hotel is Park Hotel Calama
# Retrieving Results for Index 158: Quatre Cocos
# The first hotel is Veranda Palmar Beach Hotel
# Retrieving Results for Index 159: Batagay-Alyta
# No Hotels
# ________________________________________________
# Retrieving Results for Index 160: Aykino
# The first hotel is Gostinitsa
# Retrieving Results for Index 161: Garsten
# The first hotel is Christkindlwirt
# Retrieving Results for Index 162: Upernavik
# The first hotel is Gina's Guesthouse - Upernavik
# Retrieving Results for Index 163: Port Blair
# The first hotel is Hotel Sentinel
# Retrieving Results for Index 164: Elk City
# The first hotel is Hampton Inn & Suites Elk City
# Retrieving Results for Index 165: Torbay
# The first hotel is Gallows Cove
# Retrieving Results for Index 166: Robertsport
# The first hotel is Kwepunha Retreat
# Retrieving Results for Index 167: Khanbari
# The first hotel is नेवारी फाष्टफुड एण्ड लज
# Retrieving Results for Index 168: Miran Shah
# The first hotel is Bachelor Hostel
# Retrieving Results for Index 169: Haines Junction
# The first hotel is Parkside Inn
# Retrieving Results for Index 170: Kamaishi
# The first hotel is Hotel Route Inn Kamaishi
# Retrieving Results for Index 171: Aripuanã
# No Hotels
# ________________________________________________
# Retrieving Results for Index 172: Bolobo
# No Hotels
# ________________________________________________
# Retrieving Results for Index 173: Boguchar
# The first hotel is Home on Dzerzhinskogo
# Retrieving Results for Index 174: Agüimes
# The first hotel is Hotel Villa de Aguimes
# Retrieving Results for Index 175: Avarua
# The first hotel is Paradise Inn
# Retrieving Results for Index 176: Eureka
# The first hotel is Eureka Inn
# Retrieving Results for Index 177: Coquimbo
# The first hotel is Hotel San Juan
# Retrieving Results for Index 178: Sur
# The first hotel is Sur Plaza Hotel
# Retrieving Results for Index 179: Mount Gambier
# The first hotel is Best Western Southgate Motel
# Retrieving Results for Index 180: Yamada
# The first hotel is Iroha-ya Inn
# Retrieving Results for Index 181: Dali
# The first hotel is Dali Travelling With Hostel
# Retrieving Results for Index 182: Sobolevo
# No Hotels
# ________________________________________________
# Retrieving Results for Index 183: Vila Velha
# The first hotel is Hotel Vitória Palace
# Retrieving Results for Index 184: Mahon
# The first hotel is Hotel Catalonia Mirador des Port
# Retrieving Results for Index 185: Cherskiy
# The first hotel is Gostinitsa
# Retrieving Results for Index 186: Makarov
# The first hotel is Gostinitsa ''yana''
# Retrieving Results for Index 187: Tarakan
# The first hotel is Hotel D' CaLia Tarakan
# Retrieving Results for Index 188: Vostok
# No Hotels
# ________________________________________________
# Retrieving Results for Index 189: Auki
# The first hotel is Auki Motel
# Retrieving Results for Index 190: Salalah
# The first hotel is HAMDAN PLAZA HOTEL
# Retrieving Results for Index 191: Baní
# The first hotel is Hospedaje Henriquez
# Retrieving Results for Index 192: Namatanai
# The first hotel is Namatanai Hotel
# Retrieving Results for Index 193: Muros
# The first hotel is Apartment Av. Castelao
# Retrieving Results for Index 194: Richards Bay
# The first hotel is BON Hotel Waterfront Richards Bay
# Retrieving Results for Index 195: Asău
# The first hotel is Casa Mika Ciobanus
# Retrieving Results for Index 196: Samaná
# The first hotel is The Bannister - Hotel & Yacht Club
# Retrieving Results for Index 197: Assiut
# The first hotel is Florence Hotel Assiut
# Retrieving Results for Index 198: Bandarbeyla
# The first hotel is REER XOOSHLE GROUP
# Retrieving Results for Index 199: Neath
# The first hotel is The Castle Hotel
# Retrieving Results for Index 200: Gorontalo
# The first hotel is Maqna Hotel by Prasanthi
# Retrieving Results for Index 201: Severo-Kuril'sk
# The first hotel is Kak Doma
# Retrieving Results for Index 202: Kontagora
# The first hotel is City Gate Inn
# Retrieving Results for Index 203: Luba
# No Hotels
# ________________________________________________
# Retrieving Results for Index 204: Hamilton
# The first hotel is Six Acres Bed & Breakfast
# Retrieving Results for Index 205: Mar del Plata
# The first hotel is Gran Hotel Mar del Plata habitaciones
# Retrieving Results for Index 206: Tura
# The first hotel is Hotel RIKMAN Continental
# Retrieving Results for Index 207: Jodhpur
# The first hotel is Umaid Bhawan Palace
# Retrieving Results for Index 208: Sistranda
# The first hotel is Hotell Frøya
# Retrieving Results for Index 209: Buraidah
# The first hotel is Mövenpick Hotel Qassim
# Retrieving Results for Index 210: Tommot
# The first hotel is Gostinitsa Tommot
# Retrieving Results for Index 211: Atambua
# The first hotel is Pondok Pesantren Al Muhajirin Atambua
# Retrieving Results for Index 212: Aurora
# The first hotel is Best Western Plus Gateway Inn & Suites
# Retrieving Results for Index 213: Panzhihua
# The first hotel is Electric Power Hotel
# Retrieving Results for Index 214: Lompoc
# The first hotel is Holiday Inn Express Lompoc
# Retrieving Results for Index 215: Mariinsk
# The first hotel is Hotel "Tourist"
# Retrieving Results for Index 216: Kavieng
# The first hotel is Nusa Island Retreat
# Retrieving Results for Index 217: Te Anau
# The first hotel is Kingsgate Hotel Te Anau
# Retrieving Results for Index 218: Vila Franca do Campo
# The first hotel is Pestana Bahia Praia
# Retrieving Results for Index 219: Beaupré
# The first hotel is Auberge la Camarine
# Retrieving Results for Index 220: Singaparna
# The first hotel is H. maman Sukirman "Koran"
# Retrieving Results for Index 221: Cap Malheureux
# The first hotel is Pereybere Hotel & Spa
# Retrieving Results for Index 222: Kloulklubed
# The first hotel is Storyboard Beach Resort
# Retrieving Results for Index 223: Samarai
# The first hotel is Nuli Sapi
# Retrieving Results for Index 224: Husavik
# The first hotel is Bjarnabúð
# Retrieving Results for Index 225: Cabo San Lucas
# The first hotel is Hotel Tesoro Los Cabos
# Retrieving Results for Index 226: Pisco
# The first hotel is Hostal San Isidro Oficial
# Retrieving Results for Index 227: Orange
# The first hotel is La Quinta Inn & Suites by Wyndham Irvine Spectrum
# Retrieving Results for Index 228: Touros
# The first hotel is INN NEW HORIZON
# Retrieving Results for Index 229: Naze
# The first hotel is 奄美ポートタワーホテル
# Retrieving Results for Index 230: Krasnyy Kut
# The first hotel is Yubileynaya
# Retrieving Results for Index 231: Provideniya
# No Hotels
# ________________________________________________
# Retrieving Results for Index 232: Tūkrah
# The first hotel is استراحة لاقروتا
# Retrieving Results for Index 233: Alta Floresta
# The first hotel is Floresta Amazonica Hotel
# Retrieving Results for Index 234: Thompson
# The first hotel is Burntwood Hotel
# Retrieving Results for Index 235: Malangali
# No Hotels
# ________________________________________________
# Retrieving Results for Index 236: Inta
# The first hotel is Apartments in Inta city
# Retrieving Results for Index 237: Belyy Yar
# The first hotel is Pasportnyy Stol
# Retrieving Results for Index 238: Lebu
# The first hotel is Hostal Las Lilas
# Retrieving Results for Index 239: Ovsyanka
# The first hotel is Hotel Alsey Krasnoyarsk
# Retrieving Results for Index 240: Esfarāyen
# The first hotel is Mellat
# Retrieving Results for Index 241: Esperance
# The first hotel is Hospitality Esperance
# Retrieving Results for Index 242: Pevek
# The first hotel is Severnoye Zoloto
# Retrieving Results for Index 243: Turaif
# The first hotel is Swiss Spirit Hotel & Suites Turaif
# Retrieving Results for Index 244: Aden
# The first hotel is Sama Emirate Hotel
# Retrieving Results for Index 245: Saint Anthony
# The first hotel is Holiday Inn Express Roseville-St. Paul
# Retrieving Results for Index 246: Kisangani
# The first hotel is Grand Ramela Hotel
# Retrieving Results for Index 247: Cuicatlan
# The first hotel is Cristal
# Retrieving Results for Index 248: Lahaina
# The first hotel is Lahaina Shores Beach Resort
# Retrieving Results for Index 249: Beringovskiy
# The first hotel is Beringgorski
# Retrieving Results for Index 250: Kaduqli
# The first hotel is المجلس الولائي للتخطيط الاستراتيجي
# Retrieving Results for Index 251: Barra do Garças
# The first hotel is Hotel Pousada Tropical
# Retrieving Results for Index 252: Acapulco de Juárez
# The first hotel is HS Hotsson Smart Acapulco
# Retrieving Results for Index 253: Isangel
# The first hotel is Volcano Sea View Tree House
# Retrieving Results for Index 254: Praia da Vitória
# The first hotel is Hotel Branco I
# Retrieving Results for Index 255: Praia
# The first hotel is LT Aparthotel
# Retrieving Results for Index 256: Port-Gentil
# The first hotel is Fengshui Residence
# Retrieving Results for Index 257: Virden
# The first hotel is Virden Nail Spa
# Retrieving Results for Index 258: Micheweni
# No Hotels
# ________________________________________________
# Retrieving Results for Index 259: Maceió
# The first hotel is Mercure Maceio Pajucara Hotel
# Retrieving Results for Index 260: Qeshm
# The first hotel is Kimia IV Hotel
# Retrieving Results for Index 261: Tai’an
# The first hotel is Taishan International Youth Hostel
# Retrieving Results for Index 262: Okha
# The first hotel is Империя
# Retrieving Results for Index 263: Shakiso
# The first hotel is ከለቻ Kelecha
# Retrieving Results for Index 264: Tilichiki
# No Hotels
# ________________________________________________
# Retrieving Results for Index 265: Visby
# The first hotel is Best Western Solhem Hotel Visby
# Retrieving Results for Index 266: Chālūs
# The first hotel is نظام مهندسي ساختمان چالوس
# Retrieving Results for Index 267: Khani
# The first hotel is კურორტი ზეკარი/Resort Zekari
# Retrieving Results for Index 268: Jinxiang
# The first hotel is Haiyun Holiday Hotel
# Retrieving Results for Index 269: Galle
# The first hotel is CocoBay Unawatuna
# Retrieving Results for Index 270: Zhezkazgan
# The first hotel is Kvartiry Posutochno.
# Retrieving Results for Index 271: Tadine
# No Hotels
# ________________________________________________
# Retrieving Results for Index 272: Los Llanos de Aridane
# The first hotel is Valle Aridane
# Retrieving Results for Index 273: Paita
# The first hotel is Hotel Náutico de Paita
# Retrieving Results for Index 274: Kungurtug
# No Hotels
# ________________________________________________
# Retrieving Results for Index 275: Victorville
# The first hotel is Travel Inn & Suites
# Retrieving Results for Index 276: Buala
# The first hotel is Maringe Lagoon Lodge
# Retrieving Results for Index 277: Saint-Joseph
# The first hotel is "Plantation Bed and Breakfast
# Retrieving Results for Index 278: Grand Gaube
# The first hotel is Veranda Paul et Virginie Hotel & Spa
# Retrieving Results for Index 279: Saint-Pierre
# The first hotel is Lindsey Hôtel
# Retrieving Results for Index 280: Karratha
# The first hotel is ibis Styles Karratha
# Retrieving Results for Index 281: Bethel
# The first hotel is Courtyard by Marriott Danbury
# Retrieving Results for Index 282: Inhambane
# The first hotel is MHL Turismo SA
# Retrieving Results for Index 283: Pala
# No Hotels
# ________________________________________________
# Retrieving Results for Index 284: Alanya
# The first hotel is Panorama Hotel
# Retrieving Results for Index 285: Lagos
# No Hotels
# ________________________________________________
# Retrieving Results for Index 286: Birao
# No Hotels
# ________________________________________________
# Retrieving Results for Index 287: Saurimo
# The first hotel is Hotel Kawissa Saurimo
# Retrieving Results for Index 288: Kavaratti
# The first hotel is Bismillah Hotel And Lodging
# Retrieving Results for Index 289: Sibolga
# The first hotel is Hotel Syariah CN Darussalam
# Retrieving Results for Index 290: Vardø
# The first hotel is Vardø Hotel AS
# Retrieving Results for Index 291: Alpine
# The first hotel is Ayres Lodge Alpine
# Retrieving Results for Index 292: Almeirim
# The first hotel is Ricácio Hotel
# Retrieving Results for Index 293: Rexburg
# The first hotel is AmericInn by Wyndham, Rexburg BYUI
# Retrieving Results for Index 294: Broken Hill
# The first hotel is Daydream Motel & Cottages
# Retrieving Results for Index 295: Kem'
# The first hotel is Kuzova
# Retrieving Results for Index 296: Kuusamo
# The first hotel is Hotel Kuusanka
# Retrieving Results for Index 297: Poya
# No Hotels
# ________________________________________________
# Retrieving Results for Index 298: Salta
# The first hotel is Hotel Alejandro I
# Retrieving Results for Index 299: Yavaros
# No Hotels
# ________________________________________________
# Retrieving Results for Index 300: Christchurch
# The first hotel is Chateau on the Park - Christchurch, a DoubleTree by Hilton
# Retrieving Results for Index 301: Cockburn Town
# The first hotel is Osprey Beach Hotel
# Retrieving Results for Index 302: Deputatsky
# The first hotel is Baza Otdykha
# Retrieving Results for Index 303: Vărbilău
# The first hotel is La Marele Moft
# Retrieving Results for Index 304: Yining
# The first hotel is Xiushui Hotel
# Retrieving Results for Index 305: Sola
# The first hotel is Leumerus Bungalows
# Retrieving Results for Index 306: Oyama
# The first hotel is Toyoko Inn Oyama-eki Higashi-guchi No.1
# Retrieving Results for Index 307: Ballina
# The first hotel is Ramada Hotel & Suites by Wyndham Ballina Byron
# Retrieving Results for Index 308: Paragominas
# The first hotel is HOTEL RODA VIVA
# Retrieving Results for Index 309: Maniitsoq
# The first hotel is Hotel Heilmann Lyberth
# Retrieving Results for Index 310: Ilo
# The first hotel is Torreblanca Hotel
# Retrieving Results for Index 311: San Vicente de Cañete
# The first hotel is Hotel Konford
# Retrieving Results for Index 312: Colares
# The first hotel is Arribas Sintra Hotel
# Retrieving Results for Index 313: Chui
# The first hotel is Nuevo Hotel Plaza
# Retrieving Results for Index 314: Juegang
# The first hotel is Rudong Y Hotel
# Retrieving Results for Index 315: Portland
# The first hotel is Portland Marriott City Center
# Retrieving Results for Index 316: Miguel Calmon
# The first hotel is Pousada Guiomar
# Retrieving Results for Index 317: Hauterive
# The first hotel is Aletti Palace Hotel
# Retrieving Results for Index 318: Karpogory
# The first hotel is Hotel Pinezhskaya Sloboda
# Retrieving Results for Index 319: Rantepao
# The first hotel is Hotel Luta Resort
# Retrieving Results for Index 320: Thinadhoo
# No Hotels
# ________________________________________________
# Retrieving Results for Index 321: Cabo Rojo
# The first hotel is Hotel Perichi's
# Retrieving Results for Index 322: Severnyy
# The first hotel is Full House North Mini-Hotel
# Retrieving Results for Index 323: Rawson
# The first hotel is Hotel Punta León
# Retrieving Results for Index 324: Gao
# No Hotels
# ________________________________________________
# Retrieving Results for Index 325: Yangi Marg`ilon
# The first hotel is Hotel "Ikathouse"
# Retrieving Results for Index 326: Ahipara
# The first hotel is Ahipara Holiday Park
# Retrieving Results for Index 327: Mahabalipuram
# The first hotel is Hotel Ramakrishna
# Retrieving Results for Index 328: Paoua
# The first hotel is Quartier Paoua Elien
# Retrieving Results for Index 329: Prattville
# The first hotel is InTown Suites Extended Stay Prattville AL
# Retrieving Results for Index 330: Codrington
# The first hotel is Codrington Gardens Bed And Breakfast
# Retrieving Results for Index 331: Tautira
# The first hotel is Pension Oaoa
# Retrieving Results for Index 332: Sabang
# The first hotel is Hotel Citra
# Retrieving Results for Index 333: Cayenne
# The first hotel is Hôtel Le Dronmi
# Retrieving Results for Index 334: La Ronge
# The first hotel is Northland Motor Hotel
# Retrieving Results for Index 335: Caceres
# The first hotel is Ahc Hoteles
# Retrieving Results for Index 336: Ubari
# The first hotel is فندق أوباري
# Retrieving Results for Index 337: Danielskuil
# The first hotel is Botha'Sig Gastehuis
# Retrieving Results for Index 338: Carutapera
# The first hotel is Lidera
# Retrieving Results for Index 339: Imperial Beach
# The first hotel is Motel 6 San Diego - Southbay
# Retrieving Results for Index 340: Sāndi
# The first hotel is पप्पू पान भण्डार
# Retrieving Results for Index 341: Raja
# No Hotels
# ________________________________________________
# Retrieving Results for Index 342: Ahwa
# The first hotel is GREEN ORAA HOMESTAY AHWA
# Retrieving Results for Index 343: Hohhot
# The first hotel is Sheraton Hohhot Hotel
# Retrieving Results for Index 344: Dudinka
# The first hotel is Hotel Viktoria
# Retrieving Results for Index 345: Mazamari
# The first hotel is Hospedaje Ratto
# Retrieving Results for Index 346: Kainantu
# The first hotel is Nasuke GUEST House
# Retrieving Results for Index 347: Novy Urengoy
# The first hotel is Hotel Urengoy
# Retrieving Results for Index 348: Garissa
# The first hotel is Almond Resort
# Retrieving Results for Index 349: Tekeli
# The first hotel is Profilaktoriy Tekeli
# Retrieving Results for Index 350: Makaha
# The first hotel is Hawaiian Princess Resort
# Retrieving Results for Index 351: Gambēla
# The first hotel is Solomon Debebe Hotel
# Retrieving Results for Index 352: Province of Groningen
# The first hotel is Bed&Breakfast Lageland
# Retrieving Results for Index 353: Nampula
# The first hotel is Tacab Residencial
# Retrieving Results for Index 354: Yar-Sale
# The first hotel is Yalemd
# Retrieving Results for Index 355: Cururupu
# The first hotel is Pousada Través'cia
# Retrieving Results for Index 356: Laguna
# The first hotel is Holiday Inn Express & Suites Elk Grove Central - Hwy 99
# Retrieving Results for Index 357: Northam
# The first hotel is Durrant House Hotel
# Retrieving Results for Index 358: Margate
# The first hotel is Premier Inn Margate hotel
# Retrieving Results for Index 359: Samarkand
# The first hotel is Ideal Hotel
# Retrieving Results for Index 360: San Alberto
# The first hotel is Hotel San Alberto Plaza
# Retrieving Results for Index 361: Caucayá
# The first hotel is la casona de juancho
# Retrieving Results for Index 362: Bull Savanna
# The first hotel is Big Red's
# Retrieving Results for Index 363: Port Hawkesbury
# The first hotel is MacKenzie House Tourist Home B&B
# Retrieving Results for Index 364: Sterlibashevo
# The first hotel is Zur Eni
# Retrieving Results for Index 365: Gberia Fotombu
# No Hotels
# ________________________________________________
# Retrieving Results for Index 366: Bhādra
# The first hotel is Hotel Ganpati
# Retrieving Results for Index 367: Russell
# The first hotel is Macs
# Retrieving Results for Index 368: Benguela
# The first hotel is Hotel Praia Morena
# Retrieving Results for Index 369: Sisimiut
# The first hotel is Hotel Sisimiut
# Retrieving Results for Index 370: Novorudnyy
# The first hotel is Novorudnyy
# Retrieving Results for Index 371: Atlantic City
# The first hotel is Resorts Casino Hotel
# Retrieving Results for Index 372: Kendari
# The first hotel is Hotel Wixel
# Retrieving Results for Index 373: Otavi
# The first hotel is Stop 'n Stay Otavi Rest Camp
# Retrieving Results for Index 374: Snyder
# The first hotel is Holiday Inn Express & Suites Snyder
# Retrieving Results for Index 375: Berlevåg
# The first hotel is Kvitbrakka
# Retrieving Results for Index 376: Tungor
# No Hotels
# ________________________________________________
# Retrieving Results for Index 377: Tobermory
# The first hotel is Escarpment Heights Motel
# Retrieving Results for Index 378: Agirish
# No Hotels
# ________________________________________________
# Retrieving Results for Index 379: Adré
# No Hotels
# ________________________________________________
# Retrieving Results for Index 380: Sibu
# The first hotel is RH HOTEL (4 Star)
# Retrieving Results for Index 381: Kaitangata
# The first hotel is Kaitangata Motor Camp
# Retrieving Results for Index 382: Aasiaat
# The first hotel is Hotel Aasiaat Sømandshjem
# Retrieving Results for Index 383: Manakara
# The first hotel is La Residence Manakara
# Retrieving Results for Index 384: Nelson Bay
# The first hotel is Mantra Nelson Bay
# Retrieving Results for Index 385: Galveston
# The first hotel is Comfort Inn & Suites Texas City
# Retrieving Results for Index 386: Eyl
# The first hotel is Amiin Hotel
# Retrieving Results for Index 387: Porto Walter
# The first hotel is Hotel Silva
# Retrieving Results for Index 388: Morro Bay
# The first hotel is Inn at Morro Bay
# Retrieving Results for Index 389: Kāzerūn
# The first hotel is آپارتمان بزرگ اویسا
# Retrieving Results for Index 390: Basco
# The first hotel is Nathaniel's Lodge
# Retrieving Results for Index 391: Constantine
# The first hotel is Grand Hotel Cirta
# Retrieving Results for Index 392: Lyngdal
# The first hotel is Paulsens Hotel & Cafe
# Retrieving Results for Index 393: Kudahuvadhoo
# The first hotel is Kudahuvadhoo Retreat
# Retrieving Results for Index 394: Mareeba
# The first hotel is Trinity Plains Tourist Park
# Retrieving Results for Index 395: Līsakovsk
# The first hotel is Gostinitsa "Kontinent"
# Retrieving Results for Index 396: Esim
# The first hotel is AXIM BEACH RESORT AND SPA
# Retrieving Results for Index 397: Marawi
# The first hotel is Derogongan Residence
# Retrieving Results for Index 398: Kpandae
# No Hotels
# ________________________________________________
# Retrieving Results for Index 399: Cidreira
# The first hotel is Novomar Pousada e Turismo Ltda
# Retrieving Results for Index 400: Half Moon Bay
# The first hotel is The Ritz-Carlton, Half Moon Bay
# Retrieving Results for Index 401: Taoudenni
# No Hotels
# ________________________________________________
# Retrieving Results for Index 402: Katima Mulilo
# The first hotel is Protea Hotel by Marriott Zambezi River Lodge
# Retrieving Results for Index 403: Burns Lake
# The first hotel is Burns Lake Bed and Breakfast
# Retrieving Results for Index 404: Siguiri
# No Hotels
# ________________________________________________
# Retrieving Results for Index 405: Joigny
# The first hotel is La Côte Saint Jacques & Spa
# Retrieving Results for Index 406: Jacqueville
# The first hotel is Hotel Le Martin Pecheur
# Retrieving Results for Index 407: Cartagena
# The first hotel is Allure Chocolat
# Retrieving Results for Index 408: Abu Samrah
# No Hotels
# ________________________________________________
# Retrieving Results for Index 409: Ilhabela
# The first hotel is Ilha Flat Hotel
# Retrieving Results for Index 410: Kampot
# The first hotel is Champa Lodge
# Retrieving Results for Index 411: Yerbogachën
# No Hotels
# ________________________________________________
# Retrieving Results for Index 412: Misratah
# The first hotel is فندق الماسة
# Retrieving Results for Index 413: São Miguel do Iguaçu
# The first hotel is Hotel Itaguaçu
# Retrieving Results for Index 414: Znamenskoye
# No Hotels
# ________________________________________________
# Retrieving Results for Index 415: Zelenoborskiy
# The first hotel is Turisticheskaya baza
# Retrieving Results for Index 416: Taraz
# The first hotel is Comfort Inn
# Retrieving Results for Index 417: Comodoro Rivadavia
# The first hotel is Austral Hotel
# Retrieving Results for Index 418: Sal Rei
# The first hotel is Marine Club Beach Resort
# Retrieving Results for Index 419: Baculin
# The first hotel is Shovy's Cove
# Retrieving Results for Index 420: Ulladulla
# The first hotel is Sandpiper Motel
# Retrieving Results for Index 421: Makuyuni
# No Hotels
# ________________________________________________
# Retrieving Results for Index 422: Rome
# The first hotel is Wingate By Wyndham Rome
# Retrieving Results for Index 423: Pershotravneve
# No Hotels
# ________________________________________________
# Retrieving Results for Index 424: Bahía Solano
# The first hotel is Paraiso Escondido
# Retrieving Results for Index 425: Baracoa
# The first hotel is Hostal Rio Miel
# Retrieving Results for Index 426: Ikom
# The first hotel is Reho Farm & Resort
# Retrieving Results for Index 427: Mayo
# The first hotel is Resorts Resource Group International
# Retrieving Results for Index 428: Owando
# The first hotel is Exaunel Hotel Owando
# Retrieving Results for Index 429: Vao
# The first hotel is Hotel Kou-Bugny
# Retrieving Results for Index 430: Cadereyta
# The first hotel is Hotel Maria Luisa Inn and Suites
# Retrieving Results for Index 431: Aksu
# The first hotel is Pudong Holiday Hotel
# Retrieving Results for Index 432: Cap-aux-Meules
# The first hotel is Auberge Madeli
# Retrieving Results for Index 433: Bubaque
# The first hotel is Casa Dora
# Retrieving Results for Index 434: Elizabeth City
# The first hotel is Hampton Inn Elizabeth City
# Retrieving Results for Index 435: San Rafael
# The first hotel is Hotel San Rafael
# Retrieving Results for Index 436: Maragogi
# The first hotel is Hotel Praia Dourada
# Retrieving Results for Index 437: Salé
# The first hotel is Hôtel Mercure Rabat Sheherazade
# Retrieving Results for Index 438: Philadelphia
# The first hotel is Holiday Inn Express Philadelphia-Midtown
# Retrieving Results for Index 439: Tari
# No Hotels
# ________________________________________________
# Retrieving Results for Index 440: Talakan
# No Hotels
# ________________________________________________
# Retrieving Results for Index 441: Lagoa
# The first hotel is Casa Das Faias
# Retrieving Results for Index 442: Teya
# No Hotels
# ________________________________________________
# Retrieving Results for Index 443: Tālcher
# The first hotel is Hotel Green Park
# Retrieving Results for Index 444: Natal
# The first hotel is Villa Park Hotel | Natal
# Retrieving Results for Index 445: Erbil
# The first hotel is Erbil International Hotel
# Retrieving Results for Index 446: Churhat
# The first hotel is Roshan Lal Namdeo S/o Motilal Namdeo. Prince Namdeo & Raja Namdeo
# Retrieving Results for Index 447: Clyde River
# The first hotel is Qamaq Hotel
# Retrieving Results for Index 448: Mikhaylovka
# The first hotel is 5 Komnat
# Retrieving Results for Index 449: Hede
# The first hotel is Vienna 3 Best Hotel Sheyang Jiefang Rd
# Retrieving Results for Index 450: Gamba
# No Hotels
# ________________________________________________
# Retrieving Results for Index 451: Mt. Pleasant
# The first hotel is Best Western Patriots Point
# Retrieving Results for Index 452: Strezhevoy
# The first hotel is Sibiryachka
# Retrieving Results for Index 453: Meulaboh
# The first hotel is Kost Pria
# Retrieving Results for Index 454: Gimbi
# The first hotel is Sam home
# Retrieving Results for Index 455: Lorengau
# The first hotel is Lorengau Harbourside Hotel
# Retrieving Results for Index 456: Nome
# The first hotel is Dredge 7 Inn
# Retrieving Results for Index 457: Oulainen
# The first hotel is Hotelli Ravintola Kasari
# Retrieving Results for Index 458: Burdur
# The first hotel is Alya Hotel
# Retrieving Results for Index 459: Anloga
# The first hotel is Dey Lodge
# Retrieving Results for Index 460: Taitung City
# The first hotel is Taitung Bali Suites Hotel
# Retrieving Results for Index 461: Severnoye
# The first hotel is Gostinitsa Severyanka
# Retrieving Results for Index 462: Koslan
# No Hotels
# ________________________________________________
# Retrieving Results for Index 463: Ananas
# No Hotels
# ________________________________________________
# Retrieving Results for Index 464: Coyhaique
# The first hotel is Diego De Almagro Coyhaique
# Retrieving Results for Index 465: São João da Barra
# The first hotel is Pousada Porto De Canoas
# Retrieving Results for Index 466: Saint-Augustin
# No Hotels
# ________________________________________________
# Retrieving Results for Index 467: Baranchinskiy
# No Hotels
# ________________________________________________
# Retrieving Results for Index 468: Waipawa
# The first hotel is Tora Coastal Walk
# Retrieving Results for Index 469: Bama
# The first hotel is UN Humanitarian Hub
# Retrieving Results for Index 470: Little Rock
# The first hotel is DoubleTree by Hilton Hotel Little Rock
# Retrieving Results for Index 471: Sovetskaya Gavan'
# The first hotel is Хостел "Пилигрим"
# Retrieving Results for Index 472: Kununurra
# The first hotel is Hotel Kununurra
# Retrieving Results for Index 473: Mastic Beach
# The first hotel is Brushwood House by Smith Point Beach
# Retrieving Results for Index 474: Bara
# No Hotels
# ________________________________________________
# Retrieving Results for Index 475: Hobyo
# No Hotels
# ________________________________________________
# Retrieving Results for Index 476: Ambunti
# The first hotel is Ambunti Lodge
# Retrieving Results for Index 477: Constitución
# The first hotel is Hotel Boutique Las Azucenas
# Retrieving Results for Index 478: Rocky Mountain House
# The first hotel is Walking Eagle Inn & Lodge
# Retrieving Results for Index 479: Petushki
# The first hotel is Bogdarnya
# Retrieving Results for Index 480: Macamic
# The first hotel is Maison Tardif Enr. - Auberge à Macamic, QC
# Retrieving Results for Index 481: Nawābganj
# The first hotel is দা সফ্‌ট আইটি
# Retrieving Results for Index 482: Kirkenær
# The first hotel is Skaslien Gjestgiveri
# Retrieving Results for Index 483: Ludwigsfelde
# The first hotel is B&B Hotel Berlin-Süd Genshagen
# Retrieving Results for Index 484: Arlit
# The first hotel is Hôtel Telwa Bungalow
# Retrieving Results for Index 485: São Félix do Xingu
# The first hotel is Apart Hotel Rio Xingu
# Retrieving Results for Index 486: Pangody
# The first hotel is Elizaveta Shevchuk's House
# Retrieving Results for Index 487: Stadtallendorf
# The first hotel is Parkhotel Stadtallendorf
# Retrieving Results for Index 488: Olinda
# The first hotel is Hotel 5 Sóis
# Retrieving Results for Index 489: Hirara
# The first hotel is Hotel Atoll Emerald Miyakojima
# Retrieving Results for Index 490: Makakilo City
# The first hotel is Marriott's Ko Olina Beach Club
# Retrieving Results for Index 491: Mollendo
# The first hotel is Hostal La Casa de Melgar
# Retrieving Results for Index 492: Paphos
# The first hotel is Elysium Hotel
# Retrieving Results for Index 493: Mendi
# The first hotel is Kiburu Lodge
# Retrieving Results for Index 494: Rāwah
# No Hotels
# ________________________________________________
# Retrieving Results for Index 495: Whitehorse
# The first hotel is Westmark Hotel
# Retrieving Results for Index 496: Oranjestad
# The first hotel is Divi Village Golf & Beach Resort
# Retrieving Results for Index 497: Vanimo
# The first hotel is Vahmoneh Lodge Vanimo
# Retrieving Results for Index 498: Port Macquarie
# The first hotel is Rydges Port Macquarie
# Retrieving Results for Index 499: Norman Wells
# The first hotel is Heritage Hotel
# Retrieving Results for Index 500: Bukama
# No Hotels
# ________________________________________________
# Retrieving Results for Index 501: Malanje
# The first hotel is Malanje Hotel
# Retrieving Results for Index 502: Miraflores
# The first hotel is Hotel Mansión
# Retrieving Results for Index 503: Kokopo
# The first hotel is Kokopo Beach Bungalow Resort
# Retrieving Results for Index 504: Omboué
# The first hotel is Hotel Olako
# Retrieving Results for Index 505: Penzance
# The first hotel is The Corner House
# Retrieving Results for Index 506: Baghdad
# The first hotel is Baghdad Hotel
# Retrieving Results for Index 507: Santa Cruz Cabrália
# The first hotel is Baia Cabrália Hotel
# Retrieving Results for Index 508: Takoradze
# The first hotel is Raybow International Hotel
# Retrieving Results for Index 509: Uíge
# The first hotel is Juliao Pereira
# Retrieving Results for Index 510: Klyuchi
# The first hotel is Vesolaya Mayovka
# Retrieving Results for Index 511: Todos Santos
# The first hotel is Hotel California Todos Santos
# Retrieving Results for Index 512: Camopi
# No Hotels
# ________________________________________________
# Retrieving Results for Index 513: Ciudad Río Bravo
# The first hotel is Hotel Fiesta Brava Inn
# Retrieving Results for Index 514: Seoul
# The first hotel is Lotte Hotel Seoul
# Retrieving Results for Index 515: Minas de Barroterán
# The first hotel is Motel Venecia
# Retrieving Results for Index 516: Ibrā’
# The first hotel is مزرعة راحة النفوس المنزفة
# Retrieving Results for Index 517: Rapid Valley
# The first hotel is Fairfield Inn & Suites by Marriott Rapid City
# Retrieving Results for Index 518: Najrān
# The first hotel is محمد هادي ال فطيح
# Retrieving Results for Index 519: Santa Helena de Goiás
# The first hotel is Kairós Hotel
# Retrieving Results for Index 520: Shimoda
# The first hotel is Shimoda Tokyu Hotel
# Retrieving Results for Index 521: Codajás
# The first hotel is Hotel Tamires
# Retrieving Results for Index 522: Shelburne
# The first hotel is The Retreat at the Farm
# Retrieving Results for Index 523: Hay River
# The first hotel is Ptarmigan Inn Hotels
# Retrieving Results for Index 524: Formosa
# The first hotel is Asterión Hotel
# Retrieving Results for Index 525: Burgeo
# The first hotel is Gillett's Motel
# Retrieving Results for Index 526: Metro
# The first hotel is Hotel Familie2
# Retrieving Results for Index 527: Lusambo
# No Hotels
# ________________________________________________
# Retrieving Results for Index 528: Srednekolymsk
# No Hotels
# ________________________________________________
# Retrieving Results for Index 529: Bintulu
# The first hotel is 900 Boutique INN
# Retrieving Results for Index 530: São Geraldo do Araguaia
# The first hotel is Hotel Rio Araguaia
# Retrieving Results for Index 531: Greenville
# The first hotel is Holiday Inn Express Greenville
# Retrieving Results for Index 532: Bilma
# The first hotel is Expeditions Ténére voyages
# Retrieving Results for Index 533: Kiryat Shmona
# The first hotel is Greek Relaxation
# Retrieving Results for Index 534: Dengzhou
# The first hotel is Greentree Inn Penglai Free Harbor Business Hotel
# Retrieving Results for Index 535: Matagami
# The first hotel is Motel Le Caribou
# Retrieving Results for Index 536: Verkhoyansk
# No Hotels
# ________________________________________________

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-f8dffc31712f> in <module>
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# NameError: name 'narrowed_city_df' is not defined

# %%
# Add marker layer ontop of heat map


# Display Map
